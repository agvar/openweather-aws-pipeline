# %%
#%pip install pyarrow
import sys
from pathlib import Path
import io
sys.path.append(str(Path().absolute().parent / "src"))
from IPython.display import display, HTML
# This CSS forces the table to stay wide and provides a horizontal scrollbar
style = """
<style>
    .rendered_html table {
        display: block;
        overflow-x: auto;
        white-space: nowrap !important;
    }
</style>
"""
display(HTML(style))
# Out:
# <style>
#     .rendered_html table {
#         display: block;
#         overflow-x: auto;
#         white-space: nowrap !important;
#     }
# </style>

# %%
import numpy as np
import pandas as pd
import io
from openweather_pipeline.s3_operations import S3Operations
from openweather_pipeline.config_manager import get_config

# %%
config = get_config().config
source_bucket = config.get("s3", {}).get("buckets", {}).get("source_bucket")
processed_prefix = config.get("s3", {}).get("buckets", {}).get("processed_prefix")
processed_file_name = (config.get("s3", {}).get("buckets", {}).get("processed_file_name"))
cleaned_file_name = (config.get("s3", {}).get("buckets", {}).get("cleaned_file_name"))
region = config.get("aws", {}).get("region", "us-east-1")

# %%
# Read processed parquet file
process_file_key =f"{processed_prefix}/{processed_file_name}"
s3_operations = S3Operations(bucket=source_bucket, region=region)
content = s3_operations.read_file_as_bytes(process_file_key)
df= pd.read_parquet(io.BytesIO(content))
display(df.head())
# Out:
#          date  cloud_cover  humidity  precipitation  pressure  temperature  \
# 0  2020-01-01         75.0      41.0           0.00    1008.0        38.32
# 6  2020-01-02          1.0      45.0           1.01    1015.0        45.82
# 20 2020-01-03         90.0      93.0           4.72    1009.0        45.00
# 26 2020-01-04         90.0      93.0           8.33    1003.0        47.39
# 32 2020-01-05         90.0      48.0           1.00    1011.0        39.94
#
#     temperature_min  temperature_max  wind_speed  wind_direction  zip_code  \
# 0             30.72            39.78       18.34           270.0     10001
# 6             27.99            47.03       13.96           247.0     10001
# 20            42.13            46.36        9.93           249.0     10001
# 26            41.74            48.96        9.17           320.0     10001
# 32            32.67            40.51       27.07           321.0     10001
#
#    country_code
# 0            US
# 6            US
# 20           US
# 26           US
# 32           US

# %%
# check for missing values
df.isnull().sum()
# Out:
# date               0
# cloud_cover        0
# humidity           0
# precipitation      0
# pressure           0
# temperature        0
# temperature_min    0
# temperature_max    0
# wind_speed         0
# wind_direction     0
# zip_code           0
# country_code       0
# dtype: int64

# %%
#define ranges for weather parameters
weather_ranges = {
    'cloud_cover':{'max':100,'min':0}, 
    'humidity':{'max':100,'min':0}, 
    'precipitation':{'max':10,'min':0}, 
    'pressure':{'max':1100,'min':900}, 
    'temperature':{'max':120,'min':-20}, 
    'temperature_min':{'max':120,'min':-20}, 
    'temperature_max':{'max':120,'min':-20}, 
    'wind_speed':{'max':100,'min':0}, 
    'wind_direction':{'max':360,'min':0} 
} 
weather_ranges
# Out:
# {'cloud_cover': {'max': 100, 'min': 0},
#  'humidity': {'max': 100, 'min': 0},
#  'precipitation': {'max': 10, 'min': 0},
#  'pressure': {'max': 1100, 'min': 900},
#  'temperature': {'max': 120, 'min': -20},
#  'temperature_min': {'max': 120, 'min': -20},
#  'temperature_max': {'max': 120, 'min': -20},
#  'wind_speed': {'max': 100, 'min': 0},
#  'wind_direction': {'max': 360, 'min': 0}}

# %%
#check for outliers
outlier_counts=[]
col_count=0
for col in df.columns:
    if col in weather_ranges:
        col_count = len(df[(df[col] > weather_ranges.get(col,'{}').get('max')) | (df[col] < weather_ranges.get(col,'{}').get('min'))])
    if col_count > 0:
        outlier_counts.append({col:col_count})
        col_count=0
display(outlier_counts)
# Out:
# [{'precipitation': 818}]

# %%
# check for duplicates
df[df.duplicated(subset=["date","zip_code","country_code"], keep=False)]
#remove duplicates
df= df.drop_duplicates(subset=["date","zip_code","country_code"], keep='first')

# %%
#Verify dups removed
check_dups = df[df.duplicated(subset=["date", "zip_code","country_code"], keep=False)]
check_dups
# Out:
# Empty DataFrame
# Columns: [date, cloud_cover, humidity, precipitation, pressure, temperature, temperature_min, temperature_max, wind_speed, wind_direction, zip_code, country_code]
# Index: []

# %%
# verify data types
date_cols=['date']
numeric_cols = ['cloud_cover','humidity','precipitation','pressure','temperature','temperature_min','temperature_max',
                'wind_speed','wind_direction','zip_code']
for col in date_cols:
    if df[col].dtype != 'datetime64[ns]':
        df.loc[:,col] = pd.to_datetime(df[col])
for col in numeric_cols:
    if df[col].dtype != 'float64':
        df.loc[:,col] = pd.to_numeric(df[col],errors='coerce')

# %%
# check for missing values
df.isnull().sum()
# Out:
# date               0
# cloud_cover        0
# humidity           0
# precipitation      0
# pressure           0
# temperature        0
# temperature_min    0
# temperature_max    0
# wind_speed         0
# wind_direction     0
# zip_code           0
# country_code       0
# dtype: int64

# %%
# Check for date gaps per zipcode
for zipcode in df['zip_code'].unique():
    zip_data = df[df['zip_code'] == zipcode].copy()
    zip_data = zip_data.sort_values('date')
    
    # Create expected date range
    date_range = pd.date_range(
        start=zip_data['date'].min(),
        end=zip_data['date'].max(),
        freq='D'
    )
    
    # Find missing dates
    existing_dates = set(zip_data['date'].dt.date)
    expected_dates = set(date_range.date)
    missing_dates = expected_dates - existing_dates
    
    if missing_dates:
        print(f"\nZipcode {zipcode}: {len(missing_dates)} missing dates")
        print(f"Sample missing dates: {sorted(list(missing_dates))[:5]}")
# Out:
# Zipcode 10001: 17 missing dates
# Sample missing dates: [datetime.date(2023, 4, 11), datetime.date(2023, 10, 16), datetime.date(2023, 10, 17), datetime.date(2023, 10, 18), datetime.date(2023, 11, 7)]
#
# Zipcode 10002: 17 missing dates
# Sample missing dates: [datetime.date(2022, 6, 4), datetime.date(2023, 2, 4), datetime.date(2023, 2, 10), datetime.date(2023, 4, 11), datetime.date(2023, 10, 16)]
#
# Zipcode 10003: 15 missing dates
# Sample missing dates: [datetime.date(2022, 6, 2), datetime.date(2022, 6, 5), datetime.date(2023, 4, 1), datetime.date(2023, 4, 3), datetime.date(2023, 10, 17)]
#
# Zipcode 11101: 16 missing dates
# Sample missing dates: [datetime.date(2020, 5, 22), datetime.date(2023, 10, 17), datetime.date(2023, 10, 18), datetime.date(2023, 10, 19), datetime.date(2023, 11, 9)]
#
# Zipcode 11201: 10 missing dates
# Sample missing dates: [datetime.date(2023, 2, 6), datetime.date(2023, 2, 9), datetime.date(2023, 10, 17), datetime.date(2023, 10, 18), datetime.date(2023, 10, 19)]
#
# Zipcode 12084: 19 missing dates
# Sample missing dates: [datetime.date(2022, 6, 2), datetime.date(2023, 2, 4), datetime.date(2023, 4, 2), datetime.date(2023, 4, 11), datetime.date(2023, 10, 17)]

# %%
df_sorted = df.sort_values(['zip_code','country_code','date'])

# %%
df_sorted
# Out:
#            date  cloud_cover  humidity  precipitation  pressure  temperature  \
# 0    2020-01-01         75.0      41.0           0.00    1008.0        38.32
# 6    2020-01-02          1.0      45.0           1.01    1015.0        45.82
# 20   2020-01-03         90.0      93.0           4.72    1009.0        45.00
# 26   2020-01-04         90.0      93.0           8.33    1003.0        47.39
# 32   2020-01-05         90.0      48.0           1.00    1011.0        39.94
# ...         ...          ...       ...            ...       ...          ...
# 8919 2024-02-09         75.0      55.0           0.00    1016.0        48.99
# 8925 2024-02-10         75.0      67.0           0.00    1008.0        52.23
# 8931 2024-02-11         75.0      67.0           0.00    1013.0        40.75
# 8937 2024-02-12        100.0      65.0           0.00    1012.0        37.85
# 8942 2024-02-13        100.0      63.0           0.00    1002.0        36.09
#
#       temperature_min  temperature_max  wind_speed  wind_direction  zip_code  \
# 0               30.72            39.78       18.34           270.0     10001
# 6               27.99            47.03       13.96           247.0     10001
# 20              42.13            46.36        9.93           249.0     10001
# 26              41.74            48.96        9.17           320.0     10001
# 32              32.67            40.51       27.07           321.0     10001
# ...               ...              ...         ...             ...       ...
# 8919            38.14            53.80       17.27           150.0     12084
# 8925            36.93            58.33       17.27           360.0     12084
# 8931            34.84            43.11       14.97           310.0     12084
# 8937            31.51            39.18       12.66           300.0     12084
# 8942            29.43            39.54       22.37            10.0     12084
#
#      country_code
# 0              US
# 6              US
# 20             US
# 26             US
# 32             US
# ...           ...
# 8919           US
# 8925           US
# 8931           US
# 8937           US
# 8942           US
#
# [8935 rows x 12 columns]

# %%
#Save file to s3
parquet_buffer= io.BytesIO()
df_sorted.to_parquet(parquet_buffer)
parquet_buffer.seek(0)
cleaned_file_key =f"{processed_prefix}/{cleaned_file_name}"
s3_operations.store_object_in_s3( key=cleaned_file_key, body=parquet_buffer, transfer='upload_fileobj')
